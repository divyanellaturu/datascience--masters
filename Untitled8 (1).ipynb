# %%
#min-max scaling

# %%
Min-Max scaling is a technique used in data preprocessing to rescale features so that they fall within a specific range, typically between 0 and 1. This is particularly important when machine learning models are sensitive to the magnitude of data (like in algorithms based on distances such as k-NN, SVM, or neural networks). It ensures that each feature contributes equally to the model's performance, regardless of its original scale.

How it Works
Min-Max scaling transforms a feature by scaling its values to lie within a given range, usually [0, 1]. The formula for Min-Max scaling is:

𝑋
𝑠
𝑐
𝑎
𝑙
𝑒
𝑑
=
𝑋
−
𝑋
𝑚
𝑖
𝑛
𝑋
𝑚
𝑎
𝑥
−
𝑋
𝑚
𝑖
𝑛
X
scaled
​
 =
X
max
​
 −X
min
​

X−X
min
​

​

Where:

𝑋
X is the original feature value
𝑋
𝑚
𝑖
𝑛
X
min
​
  is the minimum value of the feature in the dataset
𝑋
𝑚
𝑎
𝑥
X
max
​
  is the maximum value of the feature in the dataset
The transformed feature values will then lie between 0 and 1.

When to Use Min-Max Scaling?
When you need to scale features for algorithms that require features to be in a uniform range (e.g., neural networks, k-NN, and SVM).
When the data has known minimum and maximum bounds, and the distribution of the data is not normally distributed.
Example of Min-Max Scaling
Let's assume we have a dataset with two features: Height and Weight.

Original Dataset:
Height (cm)	Weight (kg)
150	50
160	60
170	70
180	80
190	90
We can apply Min-Max scaling to rescale these values between 0 and 1.

# %%
#unit vector

# %%
The Unit Vector technique, also known as Vector Normalization, scales the data such that the norm (or length) of each data point (row) is 1. Instead of rescaling each feature independently like in Min-Max scaling, this technique normalizes the entire feature vector representing each data point.

How it Works:
Unit Vector scaling transforms each data point so that its magnitude becomes 1. This is achieved by dividing each feature value by the vector's Euclidean norm (L2 norm). The formula for normalizing a vector
𝑋
=
[
𝑥
1
,
𝑥
2
,
.
.
.
,
𝑥
𝑛
]
X=[x
1
​
 ,x
2
​
 ,...,x
n
​
 ] is:

𝑋
𝑛
𝑜
𝑟
𝑚
𝑎
𝑙
𝑖
𝑧
𝑒
𝑑
=
𝑋
∥
𝑋
∥
X
normalized
​
 =
∥X∥
X
​

Where
∥
𝑋
∥
∥X∥ is the Euclidean norm:

∥
𝑋
∥
=
𝑥
1
2
+
𝑥
2
2
+
.
.
.
+
𝑥
𝑛
2
∥X∥=
x
1
2
​
 +x
2
2
​
 +...+x
n
2
​

​

After applying Unit Vector scaling, the sum of the squares of the components .,
∥
𝑋
𝑛
𝑜
𝑟
𝑚
𝑎
𝑙
𝑖
𝑧
𝑒
𝑑
∥
=
1
∥X
normalized
​
 ∥=1.

Difference from Min-Max Scaling:
Min-Max Scaling: Rescales each feature independently to a specific range.
